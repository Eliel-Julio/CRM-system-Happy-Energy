# %%
from Database.models import *

# %%
kit = kit(nome="Kit 14,64 kWp WEG", descricao="Description", preco_c=22000.0, n_modulos=12, inversor=True, p_modulos=610)

# %%
session.add(kit)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[28], line 2
#       1 session.add(kit)
# ----> 2 session.commit()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sqlalchemy\orm\session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sqlalchemy\orm\state_changes.py:101, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      95 current_state = self._state
#      97 if (
#      98     has_prerequisite_states
#      99     and current_state not in prerequisite_state_collection
#     100 ):
# ...

# %%
for cl, cpf_ in {'Eliel':'12345678900', 'Maria':'12345678910', 'João':'12345678901'}.items():
    cl = cliente(nome=cl, email=f'{cl.lower()}@example.com', telefone='123456789',cpf=cpf_, cidade_UF="petrolina-PE")
    session.add(cl)
session.commit()
